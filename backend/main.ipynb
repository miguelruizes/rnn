# %%
# %pip install --upgrade pip
# %pip install "numpy<2.0" pandas matplotlib scikit-learn requests joblib
# %pip install torch
# %pip install tensorflow
# %pip install flask flask-cors nltk sentencepiece sacremoses lightgbm --upgrade yfinance

#%pip install flask flask-cors numpy pandas scikit-learn nltk matplotlib requests torch tensorflow sentencepiece sacremoses lightgbm joblib
#%pip install --upgrade yfinance

from flask import Flask, jsonify, request, send_file  # Importa las clases y funciones necesarias de Flask
from flask_cors import CORS  # Importa CORS para permitir solicitudes desde otros dominios
import pandas as pd  # Importa pandas para el manejo de datos
from texto_predictivo import predecir_texto  # Importa la función predecir_texto desde el módulo texto_predictivo
from finanzas import generar_grafico_empresas  # Importa la función generar_grafico_empresas desde el módulo finanzas
from frontend import frontend_bp # Importa un blueprint personalizado desde el módulo frontend

app = Flask(__name__)  # Crea una instancia de la aplicación Flask para la API
CORS(app)  # Habilita CORS en la aplicación Flask

app.register_blueprint(frontend_bp)  # Registra un blueprint para organizar las rutas de la API


@app.route('/api/texto_predictivo', methods=['GET'])  # Define la ruta raíz de la API
def obtener_texto_predictivo():
    texto = request.args.get('texto')  # Obtiene el parámetro 'texto' de la solicitud GET con la semilla del texto a completar
    if not texto:
        return jsonify({'error': 'Falta el parámetro de texto'}), 400  # Devuelve un error si falta el parámetro
    cantidad = request.args.get('cantidad')  # Obtiene el parámetro 'cantidad' de la solicitud GET con el número de palabras a predecir
    if not cantidad:
        return jsonify({'error': 'Falta el parámetro de cantidad'}), 400  # Devuelve un error si falta el parámetro
    texto = predecir_texto(texto, int(cantidad))  # Llama a la función predecir_texto para obtener el texto completado
    return jsonify({'prediccion': texto})  # Devuelve el texto completado


@app.route('/api/finanzas/grafica', methods=['GET'])  # Define una ruta de ejemplo para la API
def obtener_grafica_finanzas():
    empresa = request.args.get('empresa')  # Obtiene el parámetro 'empresa' de la solicitud GET
    if not empresa:
        return jsonify({'error': 'Falta el parámetro de empresa'}), 400  # Devuelve un error si falta el parámetro

    periodo = request.args.get('periodo', '1y')  # Obtiene el parámetro 'periodo' de la solicitud GET, con valor por defecto '1y'
    img = generar_grafico_empresas(empresa, periodo)  # Llama a la función generar_grafico_empresas para obtener la gráfica
    return send_file(img, mimetype='image/png')  # Devuelve la imagen de la gráfica como respuesta


if __name__ == '__main__':  # Verifica si el script se está ejecutando directamente
    app.run(port=5000)  # Inicia la aplicación Flask en el puerto 5000
# Out:
# Requirement already satisfied: pip in c:\users\ferna\anaconda3\lib\site-packages (25.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy<2.0 in c:\users\ferna\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\ferna\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\ferna\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\ferna\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: requests in c:\users\ferna\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: joblib in c:\users\ferna\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ferna\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ferna\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ferna\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ferna\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ferna\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ferna\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ferna\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferna\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferna\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ferna\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\ferna\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\ferna\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\users\ferna\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ferna\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\ferna\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\ferna\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\ferna\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\ferna\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ferna\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ferna\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ferna\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in c:\users\ferna\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ferna\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ferna\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferna\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferna\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ferna\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ferna\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.4.1)
# Requirement already satisfied: pillow in c:\users\ferna\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (10.4.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ferna\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ferna\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ferna\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\ferna\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\ferna\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\ferna\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.14.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\ferna\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ferna\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ferna\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ferna\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: flask in c:\users\ferna\anaconda3\lib\site-packages (3.1.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: flask-cors in c:\users\ferna\anaconda3\lib\site-packages (6.0.1)
# Requirement already satisfied: nltk in c:\users\ferna\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: sentencepiece in c:\users\ferna\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: sacremoses in c:\users\ferna\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: lightgbm in c:\users\ferna\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: yfinance in c:\users\ferna\anaconda3\lib\site-packages (0.2.66)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\ferna\anaconda3\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\ferna\anaconda3\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\ferna\anaconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\ferna\anaconda3\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\ferna\anaconda3\lib\site-packages (from flask) (2.1.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\ferna\anaconda3\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: joblib in c:\users\ferna\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ferna\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\ferna\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ferna\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\ferna\anaconda3\lib\site-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: requests>=2.31 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (6.33.2)
# Requirement already satisfied: websockets>=13.0 in c:\users\ferna\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ferna\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: colorama in c:\users\ferna\anaconda3\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\ferna\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\ferna\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: pycparser in c:\users\ferna\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ferna\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ferna\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ferna\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ferna\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferna\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferna\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [12/Dec/2025 15:21:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Dec/2025 15:21:24] "GET /texto_predictivo/ HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Dec/2025 15:21:24] "GET /texto_predictivo/index.js HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Dec/2025 15:21:24] "GET /variables.js HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Dec/2025 15:21:33] "GET /api/texto_predictivo?texto=He%20descubierto&cantidad=10 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Dec/2025 15:21:37] "GET / HTTP/1.1" 304 -
